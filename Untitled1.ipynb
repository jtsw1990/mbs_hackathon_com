# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use("ggplot")

# %%
df = pd.read_csv(r"soln_2_impacts.csv")

# %%
df
# Out:
#    Year  ST_linear_proj  SMA_3  Proposed_impact
# 0  2016           33118  32831      33118.00000
# 1  2017           33442  33089      33442.00000
# 2  2018           33556  33372      33556.00000
# 3  2019           33426  33475      33426.00000
# 4  2020           33297  33578      33517.50465
# 5  2021           33168  33681      33572.80741

# %%
plt.figure(figsize=(15, 8))

plt.plot(df["Year"], df["ST_linear_proj"], label="Estimated COVID impact")
plt.plot(df["Year"], df["SMA_3"], label="Estimated mid term growth")
plt.plot(df["Year"], df["Proposed_impact"], "--", label="Estimated solution impact")
plt.title("Estimated impact on establishment growth 2020, 2021")
plt.legend()
